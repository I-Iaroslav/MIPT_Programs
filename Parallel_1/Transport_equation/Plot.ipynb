# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('out.txt', sep=" ", header=None)
##print(df)
Grid = np.asmatrix(df.values)[:,0:-1]
print(Grid)
# Out:
# [[ 0.00000e+00  1.00000e-02  2.00000e-02 ...  9.70000e-01  9.80000e-01
#    9.90000e-01]
#  [ 1.00000e-02  0.00000e+00  1.00000e-02 ...  9.60000e-01  9.70000e-01
#    9.80000e-01]
#  [ 2.00000e-02  1.00000e-02 -3.46945e-18 ...  9.50000e-01  9.60000e-01
#    9.70000e-01]
#  ...
#  [ 9.70000e-01  9.60000e-01  9.50000e-01 ... -3.92048e-16  1.00000e-02
#    2.00000e-02]
#  [ 9.80000e-01  9.70000e-01  9.60000e-01 ...  1.00000e-02 -3.92048e-16
#    1.00000e-02]
#  [ 9.90000e-01  9.80000e-01  9.70000e-01 ...  2.00000e-02  1.00000e-02
#   -3.92048e-16]]

# %%
fig, ax = plt.subplots(figsize = (9, 7))
extent = 0, 1, 0, 1
cb = ax.imshow(Grid, cmap=plt.cm.jet, interpolation="spline16", origin='lower', extent=extent)
fig.colorbar(cb)
fig.tight_layout()
fig.savefig("Solution.pdf")
plt.show()
